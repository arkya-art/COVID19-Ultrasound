# %%
import pandas as pd
import os
import shutil

# %%
FILE_PATH = "chestxray/metadata(1).csv"
IMAGES_PATH = "chestxray/images"

# %%
df = pd.read_csv(FILE_PATH)
df.head()
# Out:
#    patientid offset sex   age   finding survival intubated intubation_present  \
# 0          2      0   M  65.0  COVID-19        Y       NaN                NaN
# 1          2      3   M  65.0  COVID-19        Y       NaN                NaN
# 2          2      5   M  65.0  COVID-19        Y       NaN                NaN
# 3          2      6   M  65.0  COVID-19        Y       NaN                NaN
# 4          4      0   F  52.0  COVID-19      NaN       NaN                NaN
#
#   went_icu needed_supplemental_O2  ...       date  \
# 0      NaN                    NaN  ...  22-Jan-20
# 1      NaN                    NaN  ...  25-Jan-20
# 2      NaN                    NaN  ...  27-Jan-20
# 3      NaN                    NaN  ...  28-Jan-20
# 4      NaN                    NaN  ...  25-Jan-20
#
#                                             location  folder  \
# 0        Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# 1        Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# ...

# %%
df.shape
# Out:
# (354, 28)

# %%
TARGET_DIR = "Dataset/Covid"

if not os.path.exists(TARGET_DIR): # if target path not exist then create it
    
    os.mkdir(TARGET_DIR)
    print("Covid folder created")

# %%
# taking out all the images from covid dataset and place it inside new folder Covid

cnt = 0

for (i,row) in df.iterrows(): # iterating thru the rows and selecting front view covid chest xray
    
    if row["finding"] == "COVID-19" and row["view"] == "PA":
        
        # copy all the selected images from old directory to new directory
        filename = row['filename']
        image_path = os.path.join(IMAGES_PATH,filename)
        image_copy_path = os.path.join(TARGET_DIR,filename)
        shutil.copy2(image_path,image_copy_path)
        print("Moving image",cnt)
        cnt += 1
        
print(cnt) 

# there exist 142 images of covid19 with front view x ray
# Out:
# Moving image 0
# Moving image 1
# Moving image 2
# Moving image 3
# Moving image 4
# Moving image 5
# Moving image 6
# Moving image 7
# Moving image 8
# Moving image 9
# Moving image 10
# Moving image 11
# Moving image 12
# Moving image 13
# Moving image 14
# Moving image 15
# Moving image 16
# Moving image 17
# Moving image 18
# Moving image 19
# Moving image 20
# Moving image 21
# Moving image 22
# Moving image 23
# Moving image 24
# Moving image 25
# Moving image 26
# Moving image 27
# Moving image 28
# Moving image 29
# Moving image 30
# Moving image 31
# Moving image 32
# Moving image 33
# Moving image 34
# Moving image 35
# Moving image 36
# Moving image 37
# Moving image 38
# Moving image 39
# Moving image 40
# Moving image 41
# Moving image 42
# Moving image 43
# Moving image 44
# Moving image 45
# Moving image 46
# Moving image 47
# Moving image 48
# Moving image 49
# Moving image 50
# Moving image 51
# Moving image 52
# Moving image 53
# Moving image 54
# Moving image 55
# ...

# %%
# sampling of images from kaggle

import random
KAGGLE_FILE_PATH = 'chest_xray_kaggle/train/NORMAL'
TARGET_NORMAL_DIR = "Dataset/Normal"

# %%
image_names = os.listdir(KAGGLE_FILE_PATH)
image_names # lists all the images in the normal folder
# Out:
# ['IM-0115-0001.jpeg',
#  'IM-0117-0001.jpeg',
#  'IM-0119-0001.jpeg',
#  'IM-0122-0001.jpeg',
#  'IM-0125-0001.jpeg',
#  'IM-0127-0001.jpeg',
#  'IM-0128-0001.jpeg',
#  'IM-0129-0001.jpeg',
#  'IM-0131-0001.jpeg',
#  'IM-0133-0001.jpeg',
#  'IM-0135-0001.jpeg',
#  'IM-0137-0001.jpeg',
#  'IM-0140-0001.jpeg',
#  'IM-0141-0001.jpeg',
#  'IM-0143-0001.jpeg',
#  'IM-0145-0001.jpeg',
#  'IM-0147-0001.jpeg',
#  'IM-0149-0001.jpeg',
#  'IM-0151-0001.jpeg',
#  'IM-0152-0001.jpeg',
#  'IM-0154-0001.jpeg',
#  'IM-0156-0001.jpeg',
#  'IM-0158-0001.jpeg',
#  'IM-0160-0001.jpeg',
#  'IM-0162-0001.jpeg',
#  'IM-0164-0001.jpeg',
#  'IM-0166-0001.jpeg',
#  'IM-0168-0001.jpeg',
#  'IM-0170-0001.jpeg',
#  'IM-0172-0001.jpeg',
#  'IM-0176-0001.jpeg',
#  'IM-0177-0001.jpeg',
#  'IM-0178-0001.jpeg',
#  'IM-0180-0001.jpeg',
#  'IM-0182-0001.jpeg',
#  'IM-0183-0001.jpeg',
#  'IM-0185-0001.jpeg',
#  'IM-0187-0001.jpeg',
#  'IM-0189-0001.jpeg',
#  'IM-0191-0001.jpeg',
#  'IM-0193-0001.jpeg',
# ...

# %%
random.shuffle(image_names)

# %%
# picking 1st 142 images from randomly shuffled normal images
for i in range(142):
    
    image_name = image_names[i]
    image_path = os.path.join(KAGGLE_FILE_PATH,image_name)
    
    target_path = os.path.join(TARGET_NORMAL_DIR,image_name)
    
    shutil.copy2(image_path,target_path)
    print("copying image", i)
# Out:
# copying image 0
# copying image 1
# copying image 2
# copying image 3
# copying image 4
# copying image 5
# copying image 6
# copying image 7
# copying image 8
# copying image 9
# copying image 10
# copying image 11
# copying image 12
# copying image 13
# copying image 14
# copying image 15
# copying image 16
# copying image 17
# copying image 18
# copying image 19
# copying image 20
# copying image 21
# copying image 22
# copying image 23
# copying image 24
# copying image 25
# copying image 26
# copying image 27
# copying image 28
# copying image 29
# copying image 30
# copying image 31
# copying image 32
# copying image 33
# copying image 34
# copying image 35
# copying image 36
# copying image 37
# copying image 38
# copying image 39
# copying image 40
# copying image 41
# copying image 42
# copying image 43
# copying image 44
# copying image 45
# copying image 46
# copying image 47
# copying image 48
# copying image 49
# copying image 50
# copying image 51
# copying image 52
# ...

# %%
# we have taken out covid images from github dataset and normal images from kaggle dataset
